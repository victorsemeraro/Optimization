# %% [markdown]
# # <center> <u> Interest Rate Dynamics </u> </center>

# %%
import requests
import yfinance as yf
import numpy as np
import pandas as pd 

from numba import jit, prange
from scipy import stats

import seaborn as sns
import matplotlib.pyplot as plt 

from sklearn.linear_model import LinearRegression

# %% [markdown]
# ## <center> Set Seaborn Theme </center>

# %%
sns.set_theme(
    style = "darkgrid",
    palette = "bright",
)

plt.rc('figure', figsize = (10, 5))

# %% [markdown]
# ## <center> Fetch Treasury Data </center>

# %%
resp = requests.get("https://api.fiscaldata.treasury.gov/services/api/fiscal_service/v2/accounting/od/avg_interest_rates")

# %%
json = resp.json()

# %%
data = json["data"]

# %%
[(d['security_desc'], d["avg_interest_rate_amt"]) for d in data if d['security_desc'] == "Treasury Notes"]
# Out:
# [('Treasury Notes', '6.096'),
#  ('Treasury Notes', '6.076'),
#  ('Treasury Notes', '6.088'),
#  ('Treasury Notes', '6.066'),
#  ('Treasury Notes', '6.021'),
#  ('Treasury Notes', '6.018'),
#  ('Treasury Notes', '5.975')]

# %% [markdown]
# ## <center> Parse Treasury Data </center>

# %%
df = pd.read_csv("Data/AvgInterestRate.csv")

# %%
df.head()
# Out:
#   Record Date Security Type Description  \
# 0  2023-08-31                Marketable
# 1  2023-08-31                Marketable
# 2  2023-08-31                Marketable
# 3  2023-08-31                Marketable
# 4  2023-08-31                Marketable
#
#                              Security Description  \
# 0                                  Treasury Bills
# 1                                  Treasury Notes
# 2                                  Treasury Bonds
# 3  Treasury Inflation-Protected Securities (TIPS)
# 4              Treasury Floating Rate Notes (FRN)
#
#    Average Interest Rate Amount  Source Line Number  Fiscal Year  \
# 0                         5.319                   1         2023
# 1                         2.077                   2         2023
# 2                         3.045                   3         2023
# 3                         0.581                   4         2023
# 4                         5.205                   5         2023
#
#    Fiscal Quarter Number  Calendar Year  Calendar Quarter Number  \
# 0                      4           2023                        3
# 1                      4           2023                        3
# 2                      4           2023                        3
# 3                      4           2023                        3
# 4                      4           2023                        3
#
#    Calendar Month Number  Calendar Day Number
# 0                      8                   31
# 1                      8                   31
# 2                      8                   31
# 3                      8                   31
# 4                      8                   31

# %%
df.tail()
# Out:
#      Record Date Security Type Description              Security Description  \
# 4397  2001-01-31            Non-marketable  United States Savings Securities
# 4398  2001-01-31            Non-marketable         Government Account Series
# 4399  2001-01-31            Non-marketable              Total Non-marketable
# 4400  2001-01-31     Interest-bearing Debt       Total Interest-bearing Debt
# 4401  2001-01-31                Marketable                    Treasury Bills
#
#       Average Interest Rate Amount  Source Line Number  Fiscal Year  \
# 4397                         6.224                  12         2001
# 4398                         6.650                  13         2001
# 4399                         6.567                  14         2001
# 4400                         6.594                  15         2001
# 4401                         6.059                   1         2001
#
#       Fiscal Quarter Number  Calendar Year  Calendar Quarter Number  \
# 4397                      2           2001                        1
# 4398                      2           2001                        1
# 4399                      2           2001                        1
# 4400                      2           2001                        1
# 4401                      2           2001                        1
#
#       Calendar Month Number  Calendar Day Number
# 4397                      1                   31
# 4398                      1                   31
# 4399                      1                   31
# 4400                      1                   31
# 4401                      1                   31

# %%
df["Security Description"].unique()
# Out:
# array(['Treasury Bills', 'Treasury Notes', 'Treasury Bonds',
#        'Treasury Inflation-Protected Securities (TIPS)',
#        'Treasury Floating Rate Notes (FRN)', 'Federal Financing Bank',
#        'Total Marketable', 'Domestic Series', 'Special Purpose Vehicle',
#        'Foreign Series', 'State and Local Government Series',
#        'United States Savings Securities',
#        'United States Savings Inflation Securities',
#        'Government Account Series',
#        'Government Account Series Inflation Securities',
#        'Total Non-marketable', 'Total Interest-bearing Debt',
#        'Hope Bonds', 'R.E.A. Series', 'Treasury Inflation-Indexed Notes',
#        'Treasury Inflation-Indexed Bonds', 'TotalMarketable'],
#       dtype=object)

# %%
bills_df = df[df["Security Description"] == 'Treasury Bills']

# %%
bills_df.head()
# Out:
#    Record Date Security Type Description Security Description  \
# 0   2023-08-31                Marketable       Treasury Bills
# 17  2023-07-31                Marketable       Treasury Bills
# 34  2023-06-30                Marketable       Treasury Bills
# 51  2023-05-31                Marketable       Treasury Bills
# 68  2023-04-30                Marketable       Treasury Bills
#
#     Average Interest Rate Amount  Source Line Number  Fiscal Year  \
# 0                          5.319                   1         2023
# 17                         5.219                   1         2023
# 34                         5.116                   1         2023
# 51                         4.991                   1         2023
# 68                         4.739                   1         2023
#
#     Fiscal Quarter Number  Calendar Year  Calendar Quarter Number  \
# 0                       4           2023                        3
# 17                      4           2023                        3
# 34                      3           2023                        2
# 51                      3           2023                        2
# 68                      3           2023                        2
#
#     Calendar Month Number  Calendar Day Number
# 0                       8                   31
# 17                      7                   31
# 34                      6                   30
# 51                      5                   31
# 68                      4                   30

# %%
bills_df.tail()
# Out:
#      Record Date Security Type Description Security Description  \
# 4324  2001-05-31                Marketable       Treasury Bills
# 4340  2001-04-30                Marketable       Treasury Bills
# 4358  2001-03-31                Marketable       Treasury Bills
# 4372  2001-02-28                Marketable       Treasury Bills
# 4401  2001-01-31                Marketable       Treasury Bills
#
#       Average Interest Rate Amount  Source Line Number  Fiscal Year  \
# 4324                         4.560                   1         2001
# 4340                         5.076                   1         2001
# 4358                         5.369                   1         2001
# 4372                         5.755                   1         2001
# 4401                         6.059                   1         2001
#
#       Fiscal Quarter Number  Calendar Year  Calendar Quarter Number  \
# 4324                      3           2001                        2
# 4340                      3           2001                        2
# 4358                      2           2001                        1
# 4372                      2           2001                        1
# 4401                      2           2001                        1
#
#       Calendar Month Number  Calendar Day Number
# 4324                      5                   31
# 4340                      4                   30
# 4358                      3                   31
# 4372                      2                   28
# 4401                      1                   31

# %%
interest_rate = bills_df["Average Interest Rate Amount"].to_numpy()[::-1]

# %%
ax = sns.lineplot(
    interest_rate
)

plt.show()
